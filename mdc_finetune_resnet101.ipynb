# %%
import argparse
import os, sys
import shutil
import time

import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models
from utils import convert_secs2time, time_string, time_file_str
# from models import print_log
import models
import random
import numpy as np
from collections import OrderedDict

model_names = sorted(name for name in models.__dict__
                     if name.islower() and not name.startswith("__")
                     and callable(models.__dict__[name]))

model_names
# Out:
# ['alexnet',
#  'caffe_cifar',
#  'preresnet110',
#  'preresnet20',
#  'preresnet32',
#  'preresnet44',
#  'preresnet56',
#  'resnet101',
#  'resnet101_small',
#  'resnet110',
#  'resnet152',
#  'resnet152_small',
#  'resnet18',
#  'resnet18_small',
#  'resnet20',
#  'resnet32',
#  'resnet34',
#  'resnet34_small',
#  'resnet44',
#  'resnet50',
#  'resnet50_small',
#  'resnet56',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19',
#  'vgg19_bn']

# %%
# !nvidia-smi

import sys
print('__Python VERSION:', sys.version)
print('__pyTorch VERSION:', torch.__version__)
print('__CUDA VERSION')
from subprocess import call
# call(["nvcc", "--version"]) does not work
! nvcc --version
print('__CUDNN VERSION:', torch.backends.cudnn.version())
print('__Number CUDA Devices:', torch.cuda.device_count())
print('__Devices')
call(["nvidia-smi", "--format=csv", "--query-gpu=index,name,driver_version,memory.total,memory.used,memory.free"])
print('Active CUDA Device: GPU', torch.cuda.current_device())

print ('Available devices ', torch.cuda.device_count())
print ('Current cuda device ', torch.cuda.current_device())
# Out:
# Wed Oct  7 18:22:22 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.126.02   Driver Version: 418.126.02   CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:06:00.0 Off |                    0 |
# | N/A   34C    P0    42W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM2...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   34C    P0    40W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla V100-SXM2...  On   | 00000000:0A:00.0 Off |                    0 |
# | N/A   33C    P0    42W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla V100-SXM2...  On   | 00000000:0B:00.0 Off |                    0 |
# | N/A   31C    P0    40W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   4  Tesla V100-SXM2...  On   | 00000000:85:00.0 Off |                    0 |
# | N/A   32C    P0    41W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   5  Tesla V100-SXM2...  On   | 00000000:86:00.0 Off |                    0 |
# | N/A   34C    P0    40W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   6  Tesla V100-SXM2...  On   | 00000000:89:00.0 Off |                    0 |
# | N/A   34C    P0    41W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   7  Tesla V100-SXM2...  On   | 00000000:8A:00.0 Off |                    0 |
# | N/A   33C    P0    42W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# __Python VERSION: 3.6.10 |Anaconda, Inc.| (default, May  8 2020, 02:54:21)
# [GCC 7.3.0]
# __pyTorch VERSION: 1.5.0
# __CUDA VERSION
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Wed_Oct_23_19:24:38_PDT_2019
# Cuda compilation tools, release 10.2, V10.2.89
# __CUDNN VERSION: 7603
# __Number CUDA Devices: 8
# __Devices
# Active CUDA Device: GPU 0
# Available devices  8
# Current cuda device  0

# %%
from dotmap import DotMap

args = DotMap()

args.data = '/home/hongky/datasets/imagenet'
args.save_dir = '0710_resnet101/resnet101-rate-0.7/'
if not os.path.exists(args.save_dir):
    os.makedirs(args.save_dir)
    
args.arch = 'resnet101'
args.workers = 8
args.epochs = 10
args.start_epoch = 0
args.batch_size = 800
args.lr = 0.1
args.momentum = 0.9
args.weight_decay = 1e-4
args.print_freq = 200
args.resume='0510_resnet101/resnet101-rate-0.7/best.resnet101.2020-10-05-6841.pth.tar'

args.evaluate = False 
args.use_pretrain = True

# python pruning_train.py 
# -a resnet101 
# --save_dir ./snapshots/resnet101-rate-0.7 
# --rate 0.7 
# --layer_begin 0 
# --layer_end 309 
# --layer_inter 3  
# /path/to/Imagenet2012

# compress-rate
args.rate = 0.7
args.layer_begin = 0
args.layer_end = 309
args.layer_inter = 3

args.epoch_prune=1
args.skip_downsample=1
args.use_sparse=False 
args.sparse=''
args.lr_adjust=30


args.use_cuda = torch.cuda.is_available()
args.prefix = time_file_str()

print(args)
# Out:
# DotMap(data='/home/hongky/datasets/imagenet', save_dir='0710_resnet101/resnet101-rate-0.7/', arch='resnet101', workers=8, epochs=10, start_epoch=0, batch_size=800, lr=0.1, momentum=0.9, weight_decay=0.0001, print_freq=200, resume='0510_resnet101/resnet101-rate-0.7/best.resnet101.2020-10-05-6841.pth.tar', evaluate=False, use_pretrain=True, rate=0.7, layer_begin=0, layer_end=309, layer_inter=3, epoch_prune=1, skip_downsample=1, use_sparse=False, sparse='', lr_adjust=30, use_cuda=True, prefix='2020-10-07-9786')

# %%
class Mask:
    def __init__(self, model):
        self.model_size = {}
        self.model_length = {}
        self.compress_rate = {}
        self.mat = {}
        self.model = model
        self.mask_index = []

    def get_codebook(self, weight_torch, compress_rate, length):
        weight_vec = weight_torch.view(length)
        weight_np = weight_vec.cpu().numpy()

        weight_abs = np.abs(weight_np)
        weight_sort = np.sort(weight_abs)

        threshold = weight_sort[int(length * (1 - compress_rate))]
        weight_np[weight_np <= -threshold] = 1
        weight_np[weight_np >= threshold] = 1
        weight_np[weight_np != 1] = 0

        print("codebook done")
        return weight_np

    def get_filter_codebook(self, weight_torch, compress_rate, length):
        codebook = np.ones(length)
        if len(weight_torch.size()) == 4:
            filter_pruned_num = int(weight_torch.size()[0] * (1 - compress_rate))
            weight_vec = weight_torch.view(weight_torch.size()[0], -1)
            # norm1 = torch.norm(weight_vec, 1, 1)
            # norm1_np = norm1.cpu().numpy()
            norm2 = torch.norm(weight_vec, 2, 1)
            norm2_np = norm2.cpu().numpy()
            filter_index = norm2_np.argsort()[:filter_pruned_num]
            #            norm1_sort = np.sort(norm1_np)
            #            threshold = norm1_sort[int (weight_torch.size()[0] * (1-compress_rate) )]
            kernel_length = weight_torch.size()[1] * weight_torch.size()[2] * weight_torch.size()[3]
            for x in range(0, len(filter_index)):
                codebook[filter_index[x] * kernel_length: (filter_index[x] + 1) * kernel_length] = 0

            print("filter codebook done")
        else:
            pass
        return codebook

    def convert2tensor(self, x):
        x = torch.FloatTensor(x)
        return x

    def init_length(self):
        for index, item in enumerate(self.model.parameters()):
            self.model_size[index] = item.size()

        for index1 in self.model_size:
            for index2 in range(0, len(self.model_size[index1])):
                if index2 == 0:
                    self.model_length[index1] = self.model_size[index1][0]
                else:
                    self.model_length[index1] *= self.model_size[index1][index2]

    def init_rate(self, layer_rate):
        if 'vgg' in args.arch:
            cfg_5x = [24, 22, 41, 51, 108, 89, 111, 184, 276, 228, 512, 512, 512]
            cfg_official = [64, 64, 128, 128, 256, 256, 256, 512, 512, 512, 512, 512, 512]
            # cfg = [32, 64, 128, 128, 256, 256, 256, 256, 256, 256, 256, 256, 256]
            cfg_index = 0
            pre_cfg = True
            for index, item in enumerate(self.model.named_parameters()):
                self.compress_rate[index] = 1
                if len(item[1].size()) == 4:
                    print(item[1].size())
                    if not pre_cfg:
                        self.compress_rate[index] = layer_rate
                        self.mask_index.append(index)
                        print(item[0], "self.mask_index", self.mask_index)
                    else:
                        self.compress_rate[index] =  1 - cfg_5x[cfg_index] / item[1].size()[0]
                        self.mask_index.append(index)
                        print(item[0], "self.mask_index", self.mask_index, cfg_index, cfg_5x[cfg_index], item[1].size()[0],
                               )
                        cfg_index += 1
        elif "resnet" in args.arch:
            for index, item in enumerate(self.model.parameters()):
                self.compress_rate[index] = 1
            for key in range(args.layer_begin, args.layer_end + 1, args.layer_inter):
                self.compress_rate[key] = layer_rate
            if args.arch == 'resnet18':
                # last index include last fc layer
                last_index = 60
                skip_list = [21, 36, 51]
            elif args.arch == 'resnet34':
                last_index = 108
                skip_list = [27, 54, 93]
            elif args.arch == 'resnet50':
                last_index = 159
                skip_list = [12, 42, 81, 138]
            elif args.arch == 'resnet101':
                last_index = 312
                skip_list = [12, 42, 81, 291]
            elif args.arch == 'resnet152':
                last_index = 465
                skip_list = [12, 42, 117, 444]
            self.mask_index = [x for x in range(0, last_index, 3)]
            # skip downsample layer
            if args.skip_downsample == 1:
                for x in skip_list:
                    self.compress_rate[x] = 1
                    self.mask_index.remove(x)
                    print(self.mask_index)
            else:
                pass

    def init_mask(self, layer_rate):
        self.init_rate(layer_rate)
        for index, item in enumerate(self.model.parameters()):
            if (index in self.mask_index):
                self.mat[index] = self.get_filter_codebook(item.data, self.compress_rate[index],
                                                           self.model_length[index])
                self.mat[index] = self.convert2tensor(self.mat[index])
                if args.use_cuda:
                    self.mat[index] = self.mat[index].cuda()
        print("mask Ready")

    def do_mask(self):
        for index, item in enumerate(self.model.parameters()):
            if (index in self.mask_index):
                a = item.data.view(self.model_length[index])
                b = a * self.mat[index]
                item.data = b.view(self.model_size[index])
        print("mask Done")

    def if_zero(self):
        for index, item in enumerate(self.model.parameters()):
            #            if(index in self.mask_index):
            if index in [x for x in range(args.layer_begin, args.layer_end + 1, args.layer_inter)]:
                a = item.data.view(self.model_length[index])
                b = a.cpu().numpy()

                print("layer: %d, number of nonzero weight is %d, zero is %d" % (
                    index, np.count_nonzero(b), len(b) - np.count_nonzero(b)))

# %%
def import_sparse(model):
    checkpoint = torch.load(args.sparse)
    new_state_dict = OrderedDict()
    for k, v in checkpoint['state_dict'].items():
        name = k[7:]  # remove `module.`
        new_state_dict[name] = v
    model.load_state_dict(new_state_dict)
    print("sparse_model_loaded")
    return model



def validate(val_loader, model, criterion, log):
    batch_time = AverageMeter()
    losses = AverageMeter()
    top1 = AverageMeter()
    top5 = AverageMeter()

    # switch to evaluate mode
    model.eval()

    end = time.time()
    for i, (input, target) in enumerate(val_loader):
        target = target.cuda(non_blocking=True)
        input_var = torch.autograd.Variable(input, volatile=True)
        target_var = torch.autograd.Variable(target, volatile=True)

        # compute output
        output = model(input_var)
        loss = criterion(output, target_var)

        # measure accuracy and record loss
        prec1, prec5 = accuracy(output.data, target, topk=(1, 5))
        losses.update(loss.data.item(), input.size(0))
        top1.update(prec1.item(), input.size(0))
        top5.update(prec5.item(), input.size(0))

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if i % args.print_freq == 0:
            print_log('Test: [{0}/{1}]\t'
                      'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                      'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                      'Prec@1 {top1.val:.3f} ({top1.avg:.3f})\t'
                      'Prec@5 {top5.val:.3f} ({top5.avg:.3f})'.format(
                i, len(val_loader), batch_time=batch_time, loss=losses,
                top1=top1, top5=top5), log)

    print_log(' * Prec@1 {top1.avg:.3f} Prec@5 {top5.avg:.3f} Error@1 {error1:.3f}'.format(top1=top1, top5=top5,
                                                                                           error1=100 - top1.avg), log)

    return top1.avg


def save_checkpoint(state, is_best, filename, bestname):
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, bestname)


def print_log(print_string, log):
    print("{:}".format(print_string))
    log.write('{:}\n'.format(print_string))
    log.flush()


class AverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


def adjust_learning_rate(optimizer, epoch):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    lr = args.lr * (0.1 ** (epoch // args.lr_adjust))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr


def accuracy(output, target, topk=(1,)):
    """Computes the precision@k for the specified values of k"""
    maxk = max(topk)
    batch_size = target.size(0)

    _, pred = output.topk(maxk, 1, True, True)
    pred = pred.t()
    correct = pred.eq(target.view(1, -1).expand_as(pred))

    res = []
    for k in topk:
        correct_k = correct[:k].view(-1).float().sum(0, keepdim=True)
        res.append(correct_k.mul_(100.0 / batch_size))
    return res

# %%
def train(train_loader, model, criterion, optimizer, epoch, log):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    top1 = AverageMeter()
    top5 = AverageMeter()

    # switch to train mode
    model.train()

    end = time.time()
    for i, (input, target) in enumerate(train_loader):
        # measure data loading time
        data_time.update(time.time() - end)

        target = target.cuda(non_blocking=True)
        input_var = torch.autograd.Variable(input)
        target_var = torch.autograd.Variable(target)

        # compute output
        output = model(input_var)
        loss = criterion(output, target_var)

        # measure accuracy and record loss
        prec1, prec5 = accuracy(output.data, target, topk=(1, 5))
        losses.update(loss.data.item(), input.size(0))
        top1.update(prec1.item(), input.size(0))
        top5.update(prec5.item(), input.size(0))

        # compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if i % args.print_freq == 0:
            print_log('Epoch: [{0}][{1}/{2}]\t'
                      'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                      'Data {data_time.val:.3f} ({data_time.avg:.3f})\t'
                      'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                      'Prec@1 {top1.val:.3f} ({top1.avg:.3f})\t'
                      'Prec@5 {top5.val:.3f} ({top5.avg:.3f})'.format(
                epoch, i, len(train_loader), batch_time=batch_time,
                data_time=data_time, loss=losses, top1=top1, top5=top5), log)

# %%
best_prec1 = 0

if not os.path.isdir(args.save_dir):
    os.makedirs(args.save_dir)
log = open(os.path.join(args.save_dir, '{}.{}.log'.format(args.arch, args.prefix)), 'w')

# version information
print_log("PyThon  version : {}".format(sys.version.replace('\n', ' ')), log)
print_log("PyTorch version : {}".format(torch.__version__), log)
print_log("cuDNN   version : {}".format(torch.backends.cudnn.version()), log)
print_log("Vision  version : {}".format(torchvision.__version__), log)
# Out:
# PyThon  version : 3.6.10 |Anaconda, Inc.| (default, May  8 2020, 02:54:21)  [GCC 7.3.0]
# PyTorch version : 1.5.0
# cuDNN   version : 7603
# Vision  version : 0.6.0a0+82fd1c8

# %%
# create model
print_log("=> creating model '{}'".format(args.arch), log)
model = models.__dict__[args.arch](pretrained=True)
if args.use_sparse:
    model = import_sparse(model)
print_log("=> Model : {}".format(model), log)
print_log("=> parameter : {}".format(args), log)
print_log("Compress Rate: {}".format(args.rate), log)
print_log("Layer Begin: {}".format(args.layer_begin), log)
print_log("Layer End: {}".format(args.layer_end), log)
print_log("Layer Inter: {}".format(args.layer_inter), log)
print_log("Epoch prune: {}".format(args.epoch_prune), log)
print_log("Skip downsample : {}".format(args.skip_downsample), log)
print_log("Workers         : {}".format(args.workers), log)
print_log("Learning-Rate   : {}".format(args.lr), log)
print_log("Use Pre-Trained : {}".format(args.use_pretrain), log)
print_log("lr adjust : {}".format(args.lr_adjust), log)

if args.arch.startswith('alexnet') or args.arch.startswith('vgg'):
    model.features = torch.nn.DataParallel(model.features)
    model.cuda()
else:
    model = torch.nn.DataParallel(model).cuda()
    
print('Model:: ', model)
# Out:
# => creating model 'resnet101'
# => Model : ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )
# => parameter : DotMap(data='/home/hongky/datasets/imagenet', save_dir='0710_resnet101/resnet101-rate-0.7/', arch='resnet101', workers=8, epochs=10, start_epoch=0, batch_size=800, lr=0.1, momentum=0.9, weight_decay=0.0001, print_freq=200, resume='0510_resnet101/resnet101-rate-0.7/best.resnet101.2020-10-05-6841.pth.tar', evaluate=False, use_pretrain=True, rate=0.7, layer_begin=0, layer_end=309, layer_inter=3, epoch_prune=1, skip_downsample=1, use_sparse=False, sparse='', lr_adjust=30, use_cuda=True, prefix='2020-10-07-9786')
# Compress Rate: 0.7
# Layer Begin: 0
# Layer End: 309
# Layer Inter: 3
# Epoch prune: 1
# Skip downsample : 1
# Workers         : 8
# Learning-Rate   : 0.1
# Use Pre-Trained : True
# lr adjust : 30
# Model::  DataParallel(
#   (module): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (8): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (9): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (10): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (11): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (12): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (13): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (14): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (15): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (16): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (17): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (18): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (19): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (20): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (21): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (22): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#     (fc): Linear(in_features=2048, out_features=1000, bias=True)
#   )
# )

# %%
# define loss function (criterion) and optimizer
criterion = nn.CrossEntropyLoss().cuda()

optimizer = torch.optim.SGD(model.parameters(), args.lr,
                            momentum=args.momentum,
                            weight_decay=args.weight_decay,
                            nesterov=True)

# optionally resume from a checkpoint
if args.resume:
    if os.path.isfile(args.resume):
        print_log("=> loading checkpoint '{}'".format(args.resume), log)
        checkpoint = torch.load(args.resume)
        args.start_epoch = checkpoint['epoch']
        best_prec1 = checkpoint['best_prec1']
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        print_log("=> loaded checkpoint '{}' (epoch {})".format(args.resume, checkpoint['epoch']), log)
    else:
        print_log("=> no checkpoint found at '{}'".format(args.resume), log)

cudnn.benchmark = True
# Out:
# => loading checkpoint '0510_resnet101/resnet101-rate-0.7/best.resnet101.2020-10-05-6841.pth.tar'
# => loaded checkpoint '0510_resnet101/resnet101-rate-0.7/best.resnet101.2020-10-05-6841.pth.tar' (epoch 10)

# %%
# Data loading code
traindir = os.path.join(args.data, 'train')
valdir = os.path.join(args.data, 'val')
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

train_dataset = datasets.ImageFolder(
    traindir,
    transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize,
    ]))

train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=args.batch_size, shuffle=True,
    num_workers=args.workers, pin_memory=True, sampler=None)

val_loader = torch.utils.data.DataLoader(
    datasets.ImageFolder(valdir, transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize,
    ])),
    batch_size=args.batch_size, shuffle=False,
    num_workers=args.workers, pin_memory=True)

# %%
filename = os.path.join(args.save_dir, 'checkpoint.{:}.{:}.pth.tar'.format(args.arch, args.prefix))
bestname = os.path.join(args.save_dir, 'best.{:}.{:}.pth.tar'.format(args.arch, args.prefix))

m = Mask(model)

m.init_length()
print("-" * 10 + "one epoch begin" + "-" * 10)
print("the compression rate now is {:}".format(args.rate))

val_acc_1 = validate(val_loader, model, criterion, log)

print(">>>>> Accuracy_origin_model: {:}".format(val_acc_1))

m.model = model

m.init_mask(args.rate)
# m.if_zero()
m.do_mask()
model = m.model
# m.if_zero()
if args.use_cuda:
    model = model.cuda()
val_acc_2 = validate(val_loader, model, criterion, log)
print(">>>>> Accuracy_masked_model: {:}".format(val_acc_2))
# Out:
# ----------one epoch begin----------
# the compression rate now is 0.7
# /home/hongky/.conda/envs/mdc/lib/python3.6/site-packages/ipykernel_launcher.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /home/hongky/.conda/envs/mdc/lib/python3.6/site-packages/ipykernel_launcher.py:26: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# Test: [0/63]	Time 59.624 (59.624)	Loss 0.8042 (0.8042)	Prec@1 79.875 (79.875)	Prec@5 93.125 (93.125)
#  * Prec@1 64.704 Prec@5 86.688 Error@1 35.296
# >>>>> Accuracy_origin_model: 64.704
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 294, 297, 300, 303, 306, 309]
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# mask Ready
# mask Done
# Test: [0/63]	Time 21.894 (21.894)	Loss 0.8042 (0.8042)	Prec@1 79.875 (79.875)	Prec@5 93.125 (93.125)
#  * Prec@1 64.704 Prec@5 86.688 Error@1 35.296
# >>>>> Accuracy_masked_model: 64.704

# %%
start_time = time.time()
epoch_time = AverageMeter()
print(args.start_epoch, args.epochs)
args.epochs=20
for epoch in range(args.start_epoch, args.epochs):
    adjust_learning_rate(optimizer, epoch)

    need_hour, need_mins, need_secs = convert_secs2time(epoch_time.val * (args.epochs - epoch))
    need_time = '[Need: {:02d}:{:02d}:{:02d}]'.format(need_hour, need_mins, need_secs)
    print_log(
        ' [{:s}] :: {:3d}/{:3d} ----- [{:s}] {:s}'.format(
            args.arch, epoch, args.epochs, time_string(), need_time),
        log)

    
    # 1. train for one epoch
    train(train_loader, model, criterion, optimizer, epoch, log)
    

    # 2. evaluate on validation set
    val_acc_1 = validate(val_loader, model, criterion, log)
    print('\n\n>>>>> Accuracy_model: ', val_acc_1)
    
    # 3. prune trained model - filter again after 1 training epoch
    if (epoch % args.epoch_prune == 0 or epoch == args.epochs - 1):
        #        if (random.randint(1,args.epoch_prune)==1 or epoch == args.epochs-1):
        m.model = model
        m.if_zero()
        m.init_mask(args.rate)
        m.do_mask()
        m.if_zero()
        model = m.model
        if args.use_cuda:
            model = model.cuda()

    # 4. validate pruned model
    val_acc_2 = validate(val_loader, model, criterion, log)
    print('\n\n>>>>> Accuracy_pruned: ', val_acc_2)
    
    
    # remember best prec@1 and save checkpoint
    is_best = val_acc_2 > best_prec1
    best_prec1 = max(val_acc_2, best_prec1)
    save_checkpoint({
        'epoch': epoch + 1,
        'arch': args.arch,
        'state_dict': model.state_dict(),
        'best_prec1': best_prec1,
        'optimizer': optimizer.state_dict(),
    }, is_best, filename, bestname)
    # measure elapsed time
    epoch_time.update(time.time() - start_time)
    start_time = time.time()
#log.close()
# Out:
# 10 10
#  [resnet101] ::  10/ 20 ----- [[2020-10-07 07:35:10]] [Need: 00:00:00]
# Epoch: [10][0/1602]	Time 141.141 (141.141)	Data 135.446 (135.446)	Loss 1.5330 (1.5330)	Prec@1 64.250 (64.250)	Prec@5 84.125 (84.125)
# Epoch: [10][200/1602]	Time 87.180 (14.090)	Data 86.601 (13.473)	Loss 1.6086 (1.5876)	Prec@1 60.375 (62.748)	Prec@5 83.500 (83.956)
# Epoch: [10][400/1602]	Time 75.300 (13.808)	Data 74.720 (13.208)	Loss 1.3817 (1.5877)	Prec@1 65.500 (62.688)	Prec@5 87.750 (83.928)
# Epoch: [10][600/1602]	Time 43.601 (13.474)	Data 43.018 (12.878)	Loss 1.6986 (1.5955)	Prec@1 59.750 (62.520)	Prec@5 82.500 (83.807)
# Epoch: [10][800/1602]	Time 32.541 (13.156)	Data 31.957 (12.564)	Loss 1.6389 (1.6011)	Prec@1 62.500 (62.447)	Prec@5 83.125 (83.692)
# Epoch: [10][1000/1602]	Time 18.822 (11.463)	Data 18.259 (10.872)	Loss 1.6665 (1.6042)	Prec@1 59.750 (62.389)	Prec@5 82.500 (83.623)
# /home/hongky/.conda/envs/mdc/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:785: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch: [10][1200/1602]	Time 16.929 (10.204)	Data 16.348 (9.614)	Loss 1.6058 (1.6071)	Prec@1 63.000 (62.326)	Prec@5 82.125 (83.578)
# Epoch: [10][1400/1602]	Time 13.106 (9.406)	Data 12.533 (8.816)	Loss 1.5680 (1.6088)	Prec@1 63.375 (62.286)	Prec@5 84.125 (83.544)
# Epoch: [10][1600/1602]	Time 10.820 (8.870)	Data 10.246 (8.280)	Loss 1.6769 (1.6099)	Prec@1 60.625 (62.254)	Prec@5 81.250 (83.533)
# /home/hongky/.conda/envs/mdc/lib/python3.6/site-packages/ipykernel_launcher.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /home/hongky/.conda/envs/mdc/lib/python3.6/site-packages/ipykernel_launcher.py:26: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# Test: [0/63]	Time 36.474 (36.474)	Loss 0.8207 (0.8207)	Prec@1 78.625 (78.625)	Prec@5 93.500 (93.500)
#  * Prec@1 62.930 Prec@5 85.536 Error@1 37.070
#
#
# >>>>> Accuracy_model:  62.93
# layer: 0, number of nonzero weight is 6615, zero is 2793
# layer: 3, number of nonzero weight is 2880, zero is 1216
# layer: 6, number of nonzero weight is 26325, zero is 10539
# layer: 9, number of nonzero weight is 13774, zero is 2610
# layer: 12, number of nonzero weight is 16384, zero is 0
# layer: 15, number of nonzero weight is 11520, zero is 4864
# layer: 18, number of nonzero weight is 26253, zero is 10611
# layer: 21, number of nonzero weight is 14204, zero is 2180
# layer: 24, number of nonzero weight is 11520, zero is 4864
# layer: 27, number of nonzero weight is 27135, zero is 9729
# layer: 30, number of nonzero weight is 15168, zero is 1216
# layer: 33, number of nonzero weight is 23296, zero is 9472
# layer: 36, number of nonzero weight is 121698, zero is 25758
# layer: 39, number of nonzero weight is 55695, zero is 9841
# layer: 42, number of nonzero weight is 131072, zero is 0
# layer: 45, number of nonzero weight is 50984, zero is 14552
# layer: 48, number of nonzero weight is 106407, zero is 41049
# layer: 51, number of nonzero weight is 57577, zero is 7959
# layer: 54, number of nonzero weight is 49468, zero is 16068
# layer: 57, number of nonzero weight is 112410, zero is 35046
# layer: 60, number of nonzero weight is 60452, zero is 5084
# layer: 63, number of nonzero weight is 50616, zero is 14920
# layer: 66, number of nonzero weight is 108135, zero is 39321
# layer: 69, number of nonzero weight is 60487, zero is 5049
# layer: 72, number of nonzero weight is 93184, zero is 37888
# layer: 75, number of nonzero weight is 442566, zero is 147258
# layer: 78, number of nonzero weight is 226887, zero is 35257
# layer: 81, number of nonzero weight is 524288, zero is 0
# layer: 84, number of nonzero weight is 196495, zero is 65649
# layer: 87, number of nonzero weight is 419931, zero is 169893
# layer: 90, number of nonzero weight is 230212, zero is 31932
# layer: 93, number of nonzero weight is 206675, zero is 55469
# layer: 96, number of nonzero weight is 416547, zero is 173277
# layer: 99, number of nonzero weight is 232419, zero is 29725
# layer: 102, number of nonzero weight is 194186, zero is 67958
# layer: 105, number of nonzero weight is 414720, zero is 175104
# layer: 108, number of nonzero weight is 233232, zero is 28912
# layer: 111, number of nonzero weight is 194248, zero is 67896
# layer: 114, number of nonzero weight is 416430, zero is 173394
# layer: 117, number of nonzero weight is 234775, zero is 27369
# layer: 120, number of nonzero weight is 185320, zero is 76824
# layer: 123, number of nonzero weight is 414720, zero is 175104
# layer: 126, number of nonzero weight is 234671, zero is 27473
# layer: 129, number of nonzero weight is 185319, zero is 76825
# layer: 132, number of nonzero weight is 414720, zero is 175104
# layer: 135, number of nonzero weight is 234672, zero is 27472
# layer: 138, number of nonzero weight is 185316, zero is 76828
# layer: 141, number of nonzero weight is 414720, zero is 175104
# layer: 144, number of nonzero weight is 235031, zero is 27113
# layer: 147, number of nonzero weight is 185323, zero is 76821
# layer: 150, number of nonzero weight is 414720, zero is 175104
# layer: 153, number of nonzero weight is 235032, zero is 27112
# layer: 156, number of nonzero weight is 191341, zero is 70803
# layer: 159, number of nonzero weight is 414720, zero is 175104
# layer: 162, number of nonzero weight is 237732, zero is 24412
# layer: 165, number of nonzero weight is 185338, zero is 76806
# layer: 168, number of nonzero weight is 414720, zero is 175104
# layer: 171, number of nonzero weight is 238092, zero is 24052
# layer: 174, number of nonzero weight is 186360, zero is 75784
# layer: 177, number of nonzero weight is 422910, zero is 166914
# layer: 180, number of nonzero weight is 240162, zero is 21982
# layer: 183, number of nonzero weight is 189435, zero is 72709
# layer: 186, number of nonzero weight is 418050, zero is 171774
# layer: 189, number of nonzero weight is 239426, zero is 22718
# layer: 192, number of nonzero weight is 186368, zero is 75776
# layer: 195, number of nonzero weight is 417996, zero is 171828
# layer: 198, number of nonzero weight is 239426, zero is 22718
# layer: 201, number of nonzero weight is 186368, zero is 75776
# layer: 204, number of nonzero weight is 414720, zero is 175104
# layer: 207, number of nonzero weight is 238812, zero is 23332
# layer: 210, number of nonzero weight is 187392, zero is 74752
# layer: 213, number of nonzero weight is 414720, zero is 175104
# layer: 216, number of nonzero weight is 238812, zero is 23332
# layer: 219, number of nonzero weight is 188416, zero is 73728
# layer: 222, number of nonzero weight is 416376, zero is 173448
# layer: 225, number of nonzero weight is 239119, zero is 23025
# layer: 228, number of nonzero weight is 189440, zero is 72704
# layer: 231, number of nonzero weight is 414720, zero is 175104
# layer: 234, number of nonzero weight is 238812, zero is 23332
# layer: 237, number of nonzero weight is 186368, zero is 75776
# layer: 240, number of nonzero weight is 416358, zero is 173466
# layer: 243, number of nonzero weight is 239119, zero is 23025
# layer: 246, number of nonzero weight is 185344, zero is 76800
# layer: 249, number of nonzero weight is 414720, zero is 175104
# layer: 252, number of nonzero weight is 238812, zero is 23332
# layer: 255, number of nonzero weight is 184320, zero is 77824
# layer: 258, number of nonzero weight is 414720, zero is 175104
# layer: 261, number of nonzero weight is 238812, zero is 23332
# layer: 264, number of nonzero weight is 185344, zero is 76800
# layer: 267, number of nonzero weight is 414720, zero is 175104
# layer: 270, number of nonzero weight is 238812, zero is 23332
# layer: 273, number of nonzero weight is 184320, zero is 77824
# layer: 276, number of nonzero weight is 414720, zero is 175104
# layer: 279, number of nonzero weight is 238812, zero is 23332
# layer: 282, number of nonzero weight is 367616, zero is 156672
# layer: 285, number of nonzero weight is 1654272, zero is 705024
# layer: 288, number of nonzero weight is 954634, zero is 93942
# layer: 291, number of nonzero weight is 2097152, zero is 0
# layer: 294, number of nonzero weight is 737280, zero is 311296
# layer: 297, number of nonzero weight is 1654272, zero is 705024
# layer: 300, number of nonzero weight is 954634, zero is 93942
# layer: 303, number of nonzero weight is 735232, zero is 313344
# layer: 306, number of nonzero weight is 1657503, zero is 701793
# layer: 309, number of nonzero weight is 955248, zero is 93328
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 294, 297, 300, 303, 306, 309]
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# mask Ready
# mask Done
# layer: 0, number of nonzero weight is 6615, zero is 2793
# layer: 3, number of nonzero weight is 2880, zero is 1216
# layer: 6, number of nonzero weight is 25749, zero is 11115
# layer: 9, number of nonzero weight is 11430, zero is 4954
# layer: 12, number of nonzero weight is 16384, zero is 0
# layer: 15, number of nonzero weight is 11520, zero is 4864
# layer: 18, number of nonzero weight is 25920, zero is 10944
# layer: 21, number of nonzero weight is 11040, zero is 5344
# layer: 24, number of nonzero weight is 11520, zero is 4864
# layer: 27, number of nonzero weight is 25407, zero is 11457
# layer: 30, number of nonzero weight is 11184, zero is 5200
# layer: 33, number of nonzero weight is 23040, zero is 9728
# layer: 36, number of nonzero weight is 97353, zero is 50103
# layer: 39, number of nonzero weight is 45648, zero is 19888
# layer: 42, number of nonzero weight is 131072, zero is 0
# layer: 45, number of nonzero weight is 45616, zero is 19920
# layer: 48, number of nonzero weight is 103437, zero is 44019
# layer: 51, number of nonzero weight is 44622, zero is 20914
# layer: 54, number of nonzero weight is 45884, zero is 19652
# layer: 57, number of nonzero weight is 100890, zero is 46566
# layer: 60, number of nonzero weight is 45196, zero is 20340
# layer: 63, number of nonzero weight is 46016, zero is 19520
# layer: 66, number of nonzero weight is 102375, zero is 45081
# layer: 69, number of nonzero weight is 45358, zero is 20178
# layer: 72, number of nonzero weight is 92160, zero is 38912
# layer: 75, number of nonzero weight is 403398, zero is 186426
# layer: 78, number of nonzero weight is 183493, zero is 78651
# layer: 81, number of nonzero weight is 524288, zero is 0
# layer: 84, number of nonzero weight is 183709, zero is 78435
# layer: 87, number of nonzero weight is 414153, zero is 175671
# layer: 90, number of nonzero weight is 178077, zero is 84067
# layer: 93, number of nonzero weight is 183384, zero is 78760
# layer: 96, number of nonzero weight is 414243, zero is 175581
# layer: 99, number of nonzero weight is 178827, zero is 83317
# layer: 102, number of nonzero weight is 183983, zero is 78161
# layer: 105, number of nonzero weight is 414720, zero is 175104
# layer: 108, number of nonzero weight is 175648, zero is 86496
# layer: 111, number of nonzero weight is 184071, zero is 78073
# layer: 114, number of nonzero weight is 414126, zero is 175698
# layer: 117, number of nonzero weight is 176727, zero is 85417
# layer: 120, number of nonzero weight is 184296, zero is 77848
# layer: 123, number of nonzero weight is 414720, zero is 175104
# layer: 126, number of nonzero weight is 176484, zero is 85660
# layer: 129, number of nonzero weight is 184295, zero is 77849
# layer: 132, number of nonzero weight is 414720, zero is 175104
# layer: 135, number of nonzero weight is 179144, zero is 83000
# layer: 138, number of nonzero weight is 184292, zero is 77852
# layer: 141, number of nonzero weight is 414720, zero is 175104
# layer: 144, number of nonzero weight is 181272, zero is 80872
# layer: 147, number of nonzero weight is 184299, zero is 77845
# layer: 150, number of nonzero weight is 414720, zero is 175104
# layer: 153, number of nonzero weight is 181120, zero is 81024
# layer: 156, number of nonzero weight is 184173, zero is 77971
# layer: 159, number of nonzero weight is 414720, zero is 175104
# layer: 162, number of nonzero weight is 182716, zero is 79428
# layer: 165, number of nonzero weight is 184314, zero is 77830
# layer: 168, number of nonzero weight is 414720, zero is 175104
# layer: 171, number of nonzero weight is 182640, zero is 79504
# layer: 174, number of nonzero weight is 184312, zero is 77832
# layer: 177, number of nonzero weight is 411390, zero is 178434
# layer: 180, number of nonzero weight is 182203, zero is 79941
# layer: 183, number of nonzero weight is 184315, zero is 77829
# layer: 186, number of nonzero weight is 413442, zero is 176382
# layer: 189, number of nonzero weight is 183478, zero is 78666
# layer: 192, number of nonzero weight is 184320, zero is 77824
# layer: 195, number of nonzero weight is 414054, zero is 175770
# layer: 198, number of nonzero weight is 183256, zero is 78888
# layer: 201, number of nonzero weight is 184320, zero is 77824
# layer: 204, number of nonzero weight is 414720, zero is 175104
# layer: 207, number of nonzero weight is 183096, zero is 79048
# layer: 210, number of nonzero weight is 184320, zero is 77824
# layer: 213, number of nonzero weight is 414720, zero is 175104
# layer: 216, number of nonzero weight is 181728, zero is 80416
# layer: 219, number of nonzero weight is 184320, zero is 77824
# layer: 222, number of nonzero weight is 414072, zero is 175752
# layer: 225, number of nonzero weight is 182427, zero is 79717
# layer: 228, number of nonzero weight is 184320, zero is 77824
# layer: 231, number of nonzero weight is 414720, zero is 175104
# layer: 234, number of nonzero weight is 181500, zero is 80644
# layer: 237, number of nonzero weight is 184320, zero is 77824
# layer: 240, number of nonzero weight is 414054, zero is 175770
# layer: 243, number of nonzero weight is 182952, zero is 79192
# layer: 246, number of nonzero weight is 184320, zero is 77824
# layer: 249, number of nonzero weight is 414720, zero is 175104
# layer: 252, number of nonzero weight is 183324, zero is 78820
# layer: 255, number of nonzero weight is 184320, zero is 77824
# layer: 258, number of nonzero weight is 414720, zero is 175104
# layer: 261, number of nonzero weight is 183476, zero is 78668
# layer: 264, number of nonzero weight is 184320, zero is 77824
# layer: 267, number of nonzero weight is 414720, zero is 175104
# layer: 270, number of nonzero weight is 183552, zero is 78592
# layer: 273, number of nonzero weight is 184320, zero is 77824
# layer: 276, number of nonzero weight is 414720, zero is 175104
# layer: 279, number of nonzero weight is 183324, zero is 78820
# layer: 282, number of nonzero weight is 367616, zero is 156672
# layer: 285, number of nonzero weight is 1654272, zero is 705024
# layer: 288, number of nonzero weight is 734055, zero is 314521
# layer: 291, number of nonzero weight is 2097152, zero is 0
# layer: 294, number of nonzero weight is 735232, zero is 313344
# layer: 297, number of nonzero weight is 1654272, zero is 705024
# layer: 300, number of nonzero weight is 734055, zero is 314521
# layer: 303, number of nonzero weight is 735232, zero is 313344
# layer: 306, number of nonzero weight is 1652895, zero is 706401
# layer: 309, number of nonzero weight is 734208, zero is 314368
# Test: [0/63]	Time 13.935 (13.935)	Loss 0.8210 (0.8210)	Prec@1 78.500 (78.500)	Prec@5 93.750 (93.750)
#  * Prec@1 62.960 Prec@5 85.526 Error@1 37.040
#
#
# >>>>> Accuracy_pruned:  62.96
#  [resnet101] ::  11/ 20 ----- [[2020-10-07 11:37:01]] [Need: 36:16:43]
# Epoch: [11][0/1602]	Time 53.038 (53.038)	Data 52.403 (52.403)	Loss 1.6127 (1.6127)	Prec@1 62.000 (62.000)	Prec@5 82.875 (82.875)
# Epoch: [11][200/1602]	Time 16.365 (4.602)	Data 15.781 (4.012)	Loss 1.7565 (1.5709)	Prec@1 60.250 (62.973)	Prec@5 81.500 (84.075)
# Epoch: [11][400/1602]	Time 26.087 (4.381)	Data 25.500 (3.791)	Loss 1.4293 (1.5846)	Prec@1 66.500 (62.686)	Prec@5 86.875 (83.890)
# Epoch: [11][600/1602]	Time 27.644 (4.232)	Data 27.064 (3.642)	Loss 1.7185 (1.5925)	Prec@1 59.875 (62.540)	Prec@5 81.250 (83.785)
# Epoch: [11][800/1602]	Time 20.880 (4.251)	Data 20.297 (3.661)	Loss 1.5523 (1.5970)	Prec@1 62.000 (62.507)	Prec@5 84.250 (83.705)
# Epoch: [11][1000/1602]	Time 24.937 (4.180)	Data 24.334 (3.589)	Loss 1.6302 (1.6006)	Prec@1 62.875 (62.424)	Prec@5 83.750 (83.673)
# Epoch: [11][1200/1602]	Time 27.208 (4.221)	Data 26.632 (3.630)	Loss 1.6017 (1.6025)	Prec@1 63.250 (62.399)	Prec@5 82.750 (83.629)
# Epoch: [11][1400/1602]	Time 26.173 (4.473)	Data 25.594 (3.882)	Loss 1.6981 (1.6052)	Prec@1 60.875 (62.362)	Prec@5 81.375 (83.594)
# /home/hongky/.conda/envs/mdc/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:785: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch: [11][1600/1602]	Time 19.384 (4.517)	Data 18.809 (3.927)	Loss 1.7218 (1.6070)	Prec@1 61.125 (62.307)	Prec@5 82.250 (83.571)
# Test: [0/63]	Time 31.456 (31.456)	Loss 0.8120 (0.8120)	Prec@1 78.000 (78.000)	Prec@5 94.000 (94.000)
#  * Prec@1 63.318 Prec@5 85.776 Error@1 36.682
#
#
# >>>>> Accuracy_model:  63.318
# layer: 0, number of nonzero weight is 6615, zero is 2793
# layer: 3, number of nonzero weight is 2880, zero is 1216
# layer: 6, number of nonzero weight is 26325, zero is 10539
# layer: 9, number of nonzero weight is 13773, zero is 2611
# layer: 12, number of nonzero weight is 16384, zero is 0
# layer: 15, number of nonzero weight is 11520, zero is 4864
# layer: 18, number of nonzero weight is 26253, zero is 10611
# layer: 21, number of nonzero weight is 14204, zero is 2180
# layer: 24, number of nonzero weight is 11520, zero is 4864
# layer: 27, number of nonzero weight is 27128, zero is 9736
# layer: 30, number of nonzero weight is 15168, zero is 1216
# layer: 33, number of nonzero weight is 23296, zero is 9472
# layer: 36, number of nonzero weight is 121698, zero is 25758
# layer: 39, number of nonzero weight is 55695, zero is 9841
# layer: 42, number of nonzero weight is 131072, zero is 0
# layer: 45, number of nonzero weight is 50980, zero is 14556
# layer: 48, number of nonzero weight is 106407, zero is 41049
# layer: 51, number of nonzero weight is 57577, zero is 7959
# layer: 54, number of nonzero weight is 49468, zero is 16068
# layer: 57, number of nonzero weight is 112355, zero is 35101
# layer: 60, number of nonzero weight is 60451, zero is 5085
# layer: 63, number of nonzero weight is 50616, zero is 14920
# layer: 66, number of nonzero weight is 108135, zero is 39321
# layer: 69, number of nonzero weight is 60487, zero is 5049
# layer: 72, number of nonzero weight is 93184, zero is 37888
# layer: 75, number of nonzero weight is 442566, zero is 147258
# layer: 78, number of nonzero weight is 226863, zero is 35281
# layer: 81, number of nonzero weight is 524288, zero is 0
# layer: 84, number of nonzero weight is 196463, zero is 65681
# layer: 87, number of nonzero weight is 419931, zero is 169893
# layer: 90, number of nonzero weight is 230188, zero is 31956
# layer: 93, number of nonzero weight is 206670, zero is 55474
# layer: 96, number of nonzero weight is 416547, zero is 173277
# layer: 99, number of nonzero weight is 232413, zero is 29731
# layer: 102, number of nonzero weight is 194184, zero is 67960
# layer: 105, number of nonzero weight is 414720, zero is 175104
# layer: 108, number of nonzero weight is 233232, zero is 28912
# layer: 111, number of nonzero weight is 194246, zero is 67898
# layer: 114, number of nonzero weight is 416430, zero is 173394
# layer: 117, number of nonzero weight is 234774, zero is 27370
# layer: 120, number of nonzero weight is 185320, zero is 76824
# layer: 123, number of nonzero weight is 414720, zero is 175104
# layer: 126, number of nonzero weight is 234497, zero is 27647
# layer: 129, number of nonzero weight is 185319, zero is 76825
# layer: 132, number of nonzero weight is 414720, zero is 175104
# layer: 135, number of nonzero weight is 234672, zero is 27472
# layer: 138, number of nonzero weight is 185316, zero is 76828
# layer: 141, number of nonzero weight is 414720, zero is 175104
# layer: 144, number of nonzero weight is 234900, zero is 27244
# layer: 147, number of nonzero weight is 185323, zero is 76821
# layer: 150, number of nonzero weight is 414720, zero is 175104
# layer: 153, number of nonzero weight is 235032, zero is 27112
# layer: 156, number of nonzero weight is 191341, zero is 70803
# layer: 159, number of nonzero weight is 414720, zero is 175104
# layer: 162, number of nonzero weight is 237732, zero is 24412
# layer: 165, number of nonzero weight is 185338, zero is 76806
# layer: 168, number of nonzero weight is 414720, zero is 175104
# layer: 171, number of nonzero weight is 238092, zero is 24052
# layer: 174, number of nonzero weight is 186360, zero is 75784
# layer: 177, number of nonzero weight is 422910, zero is 166914
# layer: 180, number of nonzero weight is 240162, zero is 21982
# layer: 183, number of nonzero weight is 189435, zero is 72709
# layer: 186, number of nonzero weight is 418050, zero is 171774
# layer: 189, number of nonzero weight is 239426, zero is 22718
# layer: 192, number of nonzero weight is 186368, zero is 75776
# layer: 195, number of nonzero weight is 417996, zero is 171828
# layer: 198, number of nonzero weight is 239426, zero is 22718
# layer: 201, number of nonzero weight is 186368, zero is 75776
# layer: 204, number of nonzero weight is 414720, zero is 175104
# layer: 207, number of nonzero weight is 238812, zero is 23332
# layer: 210, number of nonzero weight is 187392, zero is 74752
# layer: 213, number of nonzero weight is 414720, zero is 175104
# layer: 216, number of nonzero weight is 238812, zero is 23332
# layer: 219, number of nonzero weight is 188416, zero is 73728
# layer: 222, number of nonzero weight is 416376, zero is 173448
# layer: 225, number of nonzero weight is 239119, zero is 23025
# layer: 228, number of nonzero weight is 189440, zero is 72704
# layer: 231, number of nonzero weight is 414720, zero is 175104
# layer: 234, number of nonzero weight is 238812, zero is 23332
# layer: 237, number of nonzero weight is 186368, zero is 75776
# layer: 240, number of nonzero weight is 416358, zero is 173466
# layer: 243, number of nonzero weight is 239119, zero is 23025
# layer: 246, number of nonzero weight is 185344, zero is 76800
# layer: 249, number of nonzero weight is 414720, zero is 175104
# layer: 252, number of nonzero weight is 238812, zero is 23332
# layer: 255, number of nonzero weight is 184320, zero is 77824
# layer: 258, number of nonzero weight is 414720, zero is 175104
# layer: 261, number of nonzero weight is 238812, zero is 23332
# layer: 264, number of nonzero weight is 185344, zero is 76800
# layer: 267, number of nonzero weight is 414720, zero is 175104
# layer: 270, number of nonzero weight is 238812, zero is 23332
# layer: 273, number of nonzero weight is 184320, zero is 77824
# layer: 276, number of nonzero weight is 414720, zero is 175104
# layer: 279, number of nonzero weight is 238812, zero is 23332
# layer: 282, number of nonzero weight is 367616, zero is 156672
# layer: 285, number of nonzero weight is 1654272, zero is 705024
# layer: 288, number of nonzero weight is 954634, zero is 93942
# layer: 291, number of nonzero weight is 2097152, zero is 0
# layer: 294, number of nonzero weight is 737280, zero is 311296
# layer: 297, number of nonzero weight is 1654272, zero is 705024
# layer: 300, number of nonzero weight is 954634, zero is 93942
# layer: 303, number of nonzero weight is 735232, zero is 313344
# layer: 306, number of nonzero weight is 1657503, zero is 701793
# layer: 309, number of nonzero weight is 955248, zero is 93328
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 294, 297, 300, 303, 306, 309]
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# mask Ready
# mask Done
# layer: 0, number of nonzero weight is 6615, zero is 2793
# layer: 3, number of nonzero weight is 2880, zero is 1216
# layer: 6, number of nonzero weight is 25749, zero is 11115
# layer: 9, number of nonzero weight is 11430, zero is 4954
# layer: 12, number of nonzero weight is 16384, zero is 0
# layer: 15, number of nonzero weight is 11520, zero is 4864
# layer: 18, number of nonzero weight is 25920, zero is 10944
# layer: 21, number of nonzero weight is 11100, zero is 5284
# layer: 24, number of nonzero weight is 11520, zero is 4864
# layer: 27, number of nonzero weight is 25407, zero is 11457
# layer: 30, number of nonzero weight is 11232, zero is 5152
# layer: 33, number of nonzero weight is 23040, zero is 9728
# layer: 36, number of nonzero weight is 97353, zero is 50103
# layer: 39, number of nonzero weight is 45664, zero is 19872
# layer: 42, number of nonzero weight is 131072, zero is 0
# layer: 45, number of nonzero weight is 45616, zero is 19920
# layer: 48, number of nonzero weight is 103437, zero is 44019
# layer: 51, number of nonzero weight is 44517, zero is 21019
# layer: 54, number of nonzero weight is 45884, zero is 19652
# layer: 57, number of nonzero weight is 100890, zero is 46566
# layer: 60, number of nonzero weight is 45196, zero is 20340
# layer: 63, number of nonzero weight is 46016, zero is 19520
# layer: 66, number of nonzero weight is 102375, zero is 45081
# layer: 69, number of nonzero weight is 45391, zero is 20145
# layer: 72, number of nonzero weight is 92160, zero is 38912
# layer: 75, number of nonzero weight is 403398, zero is 186426
# layer: 78, number of nonzero weight is 183493, zero is 78651
# layer: 81, number of nonzero weight is 524288, zero is 0
# layer: 84, number of nonzero weight is 183709, zero is 78435
# layer: 87, number of nonzero weight is 414153, zero is 175671
# layer: 90, number of nonzero weight is 178077, zero is 84067
# layer: 93, number of nonzero weight is 183384, zero is 78760
# layer: 96, number of nonzero weight is 414243, zero is 175581
# layer: 99, number of nonzero weight is 178827, zero is 83317
# layer: 102, number of nonzero weight is 183983, zero is 78161
# layer: 105, number of nonzero weight is 414720, zero is 175104
# layer: 108, number of nonzero weight is 175344, zero is 86800
# layer: 111, number of nonzero weight is 184071, zero is 78073
# layer: 114, number of nonzero weight is 414126, zero is 175698
# layer: 117, number of nonzero weight is 176577, zero is 85567
# layer: 120, number of nonzero weight is 184296, zero is 77848
# layer: 123, number of nonzero weight is 414720, zero is 175104
# layer: 126, number of nonzero weight is 176484, zero is 85660
# layer: 129, number of nonzero weight is 184295, zero is 77849
# layer: 132, number of nonzero weight is 414720, zero is 175104
# layer: 135, number of nonzero weight is 179144, zero is 83000
# layer: 138, number of nonzero weight is 184292, zero is 77852
# layer: 141, number of nonzero weight is 414720, zero is 175104
# layer: 144, number of nonzero weight is 181196, zero is 80948
# layer: 147, number of nonzero weight is 184299, zero is 77845
# layer: 150, number of nonzero weight is 414720, zero is 175104
# layer: 153, number of nonzero weight is 181120, zero is 81024
# layer: 156, number of nonzero weight is 184173, zero is 77971
# layer: 159, number of nonzero weight is 414720, zero is 175104
# layer: 162, number of nonzero weight is 182716, zero is 79428
# layer: 165, number of nonzero weight is 184314, zero is 77830
# layer: 168, number of nonzero weight is 414720, zero is 175104
# layer: 171, number of nonzero weight is 182564, zero is 79580
# layer: 174, number of nonzero weight is 184312, zero is 77832
# layer: 177, number of nonzero weight is 411390, zero is 178434
# layer: 180, number of nonzero weight is 182203, zero is 79941
# layer: 183, number of nonzero weight is 184315, zero is 77829
# layer: 186, number of nonzero weight is 413442, zero is 176382
# layer: 189, number of nonzero weight is 183478, zero is 78666
# layer: 192, number of nonzero weight is 184320, zero is 77824
# layer: 195, number of nonzero weight is 414054, zero is 175770
# layer: 198, number of nonzero weight is 183256, zero is 78888
# layer: 201, number of nonzero weight is 184320, zero is 77824
# layer: 204, number of nonzero weight is 414720, zero is 175104
# layer: 207, number of nonzero weight is 183096, zero is 79048
# layer: 210, number of nonzero weight is 184320, zero is 77824
# layer: 213, number of nonzero weight is 414720, zero is 175104
# layer: 216, number of nonzero weight is 181728, zero is 80416
# layer: 219, number of nonzero weight is 184320, zero is 77824
# layer: 222, number of nonzero weight is 414072, zero is 175752
# layer: 225, number of nonzero weight is 182427, zero is 79717
# layer: 228, number of nonzero weight is 184320, zero is 77824
# layer: 231, number of nonzero weight is 414720, zero is 175104
# layer: 234, number of nonzero weight is 181424, zero is 80720
# layer: 237, number of nonzero weight is 184320, zero is 77824
# layer: 240, number of nonzero weight is 414054, zero is 175770
# layer: 243, number of nonzero weight is 182952, zero is 79192
# layer: 246, number of nonzero weight is 184320, zero is 77824
# layer: 249, number of nonzero weight is 414720, zero is 175104
# layer: 252, number of nonzero weight is 183324, zero is 78820
# layer: 255, number of nonzero weight is 184320, zero is 77824
# layer: 258, number of nonzero weight is 414720, zero is 175104
# layer: 261, number of nonzero weight is 183476, zero is 78668
# layer: 264, number of nonzero weight is 184320, zero is 77824
# layer: 267, number of nonzero weight is 414720, zero is 175104
# layer: 270, number of nonzero weight is 183552, zero is 78592
# layer: 273, number of nonzero weight is 184320, zero is 77824
# layer: 276, number of nonzero weight is 414720, zero is 175104
# layer: 279, number of nonzero weight is 183324, zero is 78820
# layer: 282, number of nonzero weight is 367616, zero is 156672
# layer: 285, number of nonzero weight is 1654272, zero is 705024
# layer: 288, number of nonzero weight is 734055, zero is 314521
# layer: 291, number of nonzero weight is 2097152, zero is 0
# layer: 294, number of nonzero weight is 735232, zero is 313344
# layer: 297, number of nonzero weight is 1654272, zero is 705024
# layer: 300, number of nonzero weight is 734055, zero is 314521
# layer: 303, number of nonzero weight is 735232, zero is 313344
# layer: 306, number of nonzero weight is 1652895, zero is 706401
# layer: 309, number of nonzero weight is 734208, zero is 314368
# Test: [0/63]	Time 13.198 (13.198)	Loss 0.8159 (0.8159)	Prec@1 77.875 (77.875)	Prec@5 93.875 (93.875)
#  * Prec@1 63.292 Prec@5 85.824 Error@1 36.708
#
#
# >>>>> Accuracy_pruned:  63.292
#  [resnet101] ::  12/ 20 ----- [[2020-10-07 13:42:12]] [Need: 16:41:26]
# Epoch: [12][0/1602]	Time 43.251 (43.251)	Data 42.557 (42.557)	Loss 1.5182 (1.5182)	Prec@1 64.500 (64.500)	Prec@5 84.625 (84.625)
# Epoch: [12][200/1602]	Time 17.588 (3.748)	Data 17.023 (3.148)	Loss 1.4835 (1.5764)	Prec@1 64.125 (62.887)	Prec@5 85.250 (84.012)
# Epoch: [12][400/1602]	Time 24.160 (3.504)	Data 23.580 (2.904)	Loss 1.5199 (1.5799)	Prec@1 63.875 (62.802)	Prec@5 85.375 (83.927)
# Epoch: [12][600/1602]	Time 34.691 (3.637)	Data 34.102 (3.036)	Loss 1.4787 (1.5854)	Prec@1 64.375 (62.745)	Prec@5 85.750 (83.867)
# Epoch: [12][800/1602]	Time 33.524 (3.909)	Data 32.943 (3.310)	Loss 1.5727 (1.5908)	Prec@1 62.125 (62.600)	Prec@5 84.125 (83.828)
# Epoch: [12][1000/1602]	Time 32.844 (4.194)	Data 32.262 (3.596)	Loss 1.5635 (1.5952)	Prec@1 62.375 (62.528)	Prec@5 83.000 (83.754)
# Epoch: [12][1200/1602]	Time 41.190 (4.456)	Data 40.603 (3.859)	Loss 1.7432 (1.5995)	Prec@1 58.750 (62.417)	Prec@5 81.500 (83.690)
# Epoch: [12][1400/1602]	Time 30.832 (4.620)	Data 30.268 (4.025)	Loss 1.5620 (1.6016)	Prec@1 64.125 (62.389)	Prec@5 84.500 (83.660)
# /home/hongky/.conda/envs/mdc/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:785: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch: [12][1600/1602]	Time 34.392 (4.658)	Data 33.816 (4.063)	Loss 1.5854 (1.6050)	Prec@1 62.000 (62.328)	Prec@5 84.875 (83.618)
# Test: [0/63]	Time 31.752 (31.752)	Loss 0.7587 (0.7587)	Prec@1 80.375 (80.375)	Prec@5 94.000 (94.000)
#  * Prec@1 64.360 Prec@5 86.596 Error@1 35.640
#
#
# >>>>> Accuracy_model:  64.36
# layer: 0, number of nonzero weight is 6615, zero is 2793
# layer: 3, number of nonzero weight is 2880, zero is 1216
# layer: 6, number of nonzero weight is 26317, zero is 10547
# layer: 9, number of nonzero weight is 13772, zero is 2612
# layer: 12, number of nonzero weight is 16384, zero is 0
# layer: 15, number of nonzero weight is 11520, zero is 4864
# layer: 18, number of nonzero weight is 26253, zero is 10611
# layer: 21, number of nonzero weight is 14167, zero is 2217
# layer: 24, number of nonzero weight is 11520, zero is 4864
# layer: 27, number of nonzero weight is 27020, zero is 9844
# layer: 30, number of nonzero weight is 15168, zero is 1216
# layer: 33, number of nonzero weight is 23296, zero is 9472
# layer: 36, number of nonzero weight is 121698, zero is 25758
# layer: 39, number of nonzero weight is 55683, zero is 9853
# layer: 42, number of nonzero weight is 131072, zero is 0
# layer: 45, number of nonzero weight is 50768, zero is 14768
# layer: 48, number of nonzero weight is 106407, zero is 41049
# layer: 51, number of nonzero weight is 57576, zero is 7960
# layer: 54, number of nonzero weight is 49440, zero is 16096
# layer: 57, number of nonzero weight is 111996, zero is 35460
# layer: 60, number of nonzero weight is 60447, zero is 5089
# layer: 63, number of nonzero weight is 50610, zero is 14926
# layer: 66, number of nonzero weight is 108135, zero is 39321
# layer: 69, number of nonzero weight is 60485, zero is 5051
# layer: 72, number of nonzero weight is 93184, zero is 37888
# layer: 75, number of nonzero weight is 442566, zero is 147258
# layer: 78, number of nonzero weight is 226644, zero is 35500
# layer: 81, number of nonzero weight is 524288, zero is 0
# layer: 84, number of nonzero weight is 195975, zero is 66169
# layer: 87, number of nonzero weight is 419928, zero is 169896
# layer: 90, number of nonzero weight is 230140, zero is 32004
# layer: 93, number of nonzero weight is 206200, zero is 55944
# layer: 96, number of nonzero weight is 416545, zero is 173279
# layer: 99, number of nonzero weight is 232390, zero is 29754
# layer: 102, number of nonzero weight is 194028, zero is 68116
# layer: 105, number of nonzero weight is 414720, zero is 175104
# layer: 108, number of nonzero weight is 233137, zero is 29007
# layer: 111, number of nonzero weight is 194118, zero is 68026
# layer: 114, number of nonzero weight is 416430, zero is 173394
# layer: 117, number of nonzero weight is 234696, zero is 27448
# layer: 120, number of nonzero weight is 185304, zero is 76840
# layer: 123, number of nonzero weight is 414720, zero is 175104
# layer: 126, number of nonzero weight is 234481, zero is 27663
# layer: 129, number of nonzero weight is 185300, zero is 76844
# layer: 132, number of nonzero weight is 414720, zero is 175104
# layer: 135, number of nonzero weight is 234490, zero is 27654
# layer: 138, number of nonzero weight is 185300, zero is 76844
# layer: 141, number of nonzero weight is 414720, zero is 175104
# layer: 144, number of nonzero weight is 234849, zero is 27295
# layer: 147, number of nonzero weight is 185310, zero is 76834
# layer: 150, number of nonzero weight is 414720, zero is 175104
# layer: 153, number of nonzero weight is 235027, zero is 27117
# layer: 156, number of nonzero weight is 191249, zero is 70895
# layer: 159, number of nonzero weight is 414720, zero is 175104
# layer: 162, number of nonzero weight is 237732, zero is 24412
# layer: 165, number of nonzero weight is 185337, zero is 76807
# layer: 168, number of nonzero weight is 414720, zero is 175104
# layer: 171, number of nonzero weight is 238092, zero is 24052
# layer: 174, number of nonzero weight is 186360, zero is 75784
# layer: 177, number of nonzero weight is 422909, zero is 166915
# layer: 180, number of nonzero weight is 240160, zero is 21984
# layer: 183, number of nonzero weight is 189435, zero is 72709
# layer: 186, number of nonzero weight is 418050, zero is 171774
# layer: 189, number of nonzero weight is 239426, zero is 22718
# layer: 192, number of nonzero weight is 186368, zero is 75776
# layer: 195, number of nonzero weight is 417996, zero is 171828
# layer: 198, number of nonzero weight is 239425, zero is 22719
# layer: 201, number of nonzero weight is 186368, zero is 75776
# layer: 204, number of nonzero weight is 414720, zero is 175104
# layer: 207, number of nonzero weight is 238812, zero is 23332
# layer: 210, number of nonzero weight is 187392, zero is 74752
# layer: 213, number of nonzero weight is 414720, zero is 175104
# layer: 216, number of nonzero weight is 238812, zero is 23332
# layer: 219, number of nonzero weight is 188416, zero is 73728
# layer: 222, number of nonzero weight is 416375, zero is 173449
# layer: 225, number of nonzero weight is 239119, zero is 23025
# layer: 228, number of nonzero weight is 189440, zero is 72704
# layer: 231, number of nonzero weight is 414720, zero is 175104
# layer: 234, number of nonzero weight is 238812, zero is 23332
# layer: 237, number of nonzero weight is 186368, zero is 75776
# layer: 240, number of nonzero weight is 416358, zero is 173466
# layer: 243, number of nonzero weight is 239119, zero is 23025
# layer: 246, number of nonzero weight is 185344, zero is 76800
# layer: 249, number of nonzero weight is 414720, zero is 175104
# layer: 252, number of nonzero weight is 238812, zero is 23332
# layer: 255, number of nonzero weight is 184320, zero is 77824
# layer: 258, number of nonzero weight is 414720, zero is 175104
# layer: 261, number of nonzero weight is 238812, zero is 23332
# layer: 264, number of nonzero weight is 185344, zero is 76800
# layer: 267, number of nonzero weight is 414720, zero is 175104
# layer: 270, number of nonzero weight is 238812, zero is 23332
# layer: 273, number of nonzero weight is 184320, zero is 77824
# layer: 276, number of nonzero weight is 414720, zero is 175104
# layer: 279, number of nonzero weight is 238812, zero is 23332
# layer: 282, number of nonzero weight is 367616, zero is 156672
# layer: 285, number of nonzero weight is 1654272, zero is 705024
# layer: 288, number of nonzero weight is 954634, zero is 93942
# layer: 291, number of nonzero weight is 2097152, zero is 0
# layer: 294, number of nonzero weight is 737280, zero is 311296
# layer: 297, number of nonzero weight is 1654272, zero is 705024
# layer: 300, number of nonzero weight is 954634, zero is 93942
# layer: 303, number of nonzero weight is 735232, zero is 313344
# layer: 306, number of nonzero weight is 1657503, zero is 701793
# layer: 309, number of nonzero weight is 955248, zero is 93328
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 294, 297, 300, 303, 306, 309]
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# ...
# layer: 51, number of nonzero weight is 55968, zero is 9568
# layer: 54, number of nonzero weight is 46365, zero is 19171
# layer: 57, number of nonzero weight is 100890, zero is 46566
# layer: 60, number of nonzero weight is 57891, zero is 7645
# layer: 63, number of nonzero weight is 47024, zero is 18512
# layer: 66, number of nonzero weight is 102375, zero is 45081
# layer: 69, number of nonzero weight is 59107, zero is 6429
# layer: 72, number of nonzero weight is 92160, zero is 38912
# layer: 75, number of nonzero weight is 405009, zero is 184815
# layer: 78, number of nonzero weight is 222149, zero is 39995
# layer: 81, number of nonzero weight is 524288, zero is 0
# layer: 84, number of nonzero weight is 185956, zero is 76188
# layer: 87, number of nonzero weight is 414153, zero is 175671
# layer: 90, number of nonzero weight is 223846, zero is 38298
# layer: 93, number of nonzero weight is 187996, zero is 74148
# layer: 96, number of nonzero weight is 414243, zero is 175581
# layer: 99, number of nonzero weight is 226240, zero is 35904
# layer: 102, number of nonzero weight is 183983, zero is 78161
# layer: 105, number of nonzero weight is 414720, zero is 175104
# layer: 108, number of nonzero weight is 224532, zero is 37612
# layer: 111, number of nonzero weight is 184071, zero is 78073
# layer: 114, number of nonzero weight is 414126, zero is 175698
# layer: 117, number of nonzero weight is 227087, zero is 35057
# layer: 120, number of nonzero weight is 184296, zero is 77848
# layer: 123, number of nonzero weight is 414720, zero is 175104
# layer: 126, number of nonzero weight is 227255, zero is 34889
# layer: 129, number of nonzero weight is 184295, zero is 77849
# layer: 132, number of nonzero weight is 414720, zero is 175104
# layer: 135, number of nonzero weight is 228980, zero is 33164
# layer: 138, number of nonzero weight is 184292, zero is 77852
# layer: 141, number of nonzero weight is 414720, zero is 175104
# layer: 144, number of nonzero weight is 231840, zero is 30304
# layer: 147, number of nonzero weight is 184299, zero is 77845
# layer: 150, number of nonzero weight is 414720, zero is 175104
# layer: 153, number of nonzero weight is 231655, zero is 30489
# layer: 156, number of nonzero weight is 184173, zero is 77971
# layer: 159, number of nonzero weight is 414720, zero is 175104
# layer: 162, number of nonzero weight is 236439, zero is 25705
# layer: 165, number of nonzero weight is 184314, zero is 77830
# layer: 168, number of nonzero weight is 414720, zero is 175104
# layer: 171, number of nonzero weight is 237152, zero is 24992
# layer: 174, number of nonzero weight is 184312, zero is 77832
# layer: 177, number of nonzero weight is 411390, zero is 178434
# layer: 180, number of nonzero weight is 236639, zero is 25505
# layer: 183, number of nonzero weight is 184315, zero is 77829
# layer: 186, number of nonzero weight is 413442, zero is 176382
# layer: 189, number of nonzero weight is 238547, zero is 23597
# layer: 192, number of nonzero weight is 184320, zero is 77824
# layer: 195, number of nonzero weight is 414054, zero is 175770
# layer: 198, number of nonzero weight is 238336, zero is 23808
# layer: 201, number of nonzero weight is 184320, zero is 77824
# layer: 204, number of nonzero weight is 414720, zero is 175104
# layer: 207, number of nonzero weight is 238432, zero is 23712
# layer: 210, number of nonzero weight is 184320, zero is 77824
# layer: 213, number of nonzero weight is 414720, zero is 175104
# layer: 216, number of nonzero weight is 237064, zero is 25080
# layer: 219, number of nonzero weight is 184320, zero is 77824
# layer: 222, number of nonzero weight is 414072, zero is 175752
# layer: 225, number of nonzero weight is 237812, zero is 24332
# layer: 228, number of nonzero weight is 184320, zero is 77824
# layer: 231, number of nonzero weight is 414720, zero is 175104
# layer: 234, number of nonzero weight is 237064, zero is 25080
# layer: 237, number of nonzero weight is 184320, zero is 77824
# layer: 240, number of nonzero weight is 414054, zero is 175770
# layer: 243, number of nonzero weight is 238258, zero is 23886
# layer: 246, number of nonzero weight is 185344, zero is 76800
# layer: 249, number of nonzero weight is 414720, zero is 175104
# layer: 252, number of nonzero weight is 238584, zero is 23560
# layer: 255, number of nonzero weight is 184320, zero is 77824
# layer: 258, number of nonzero weight is 414720, zero is 175104
# layer: 261, number of nonzero weight is 238736, zero is 23408
# layer: 264, number of nonzero weight is 184320, zero is 77824
# layer: 267, number of nonzero weight is 414720, zero is 175104
# layer: 270, number of nonzero weight is 238812, zero is 23332
# layer: 273, number of nonzero weight is 184320, zero is 77824
# layer: 276, number of nonzero weight is 414720, zero is 175104
# layer: 279, number of nonzero weight is 238277, zero is 23867
# layer: 282, number of nonzero weight is 367616, zero is 156672
# layer: 285, number of nonzero weight is 1654272, zero is 705024
# layer: 288, number of nonzero weight is 954481, zero is 94095
# layer: 291, number of nonzero weight is 2097152, zero is 0
# layer: 294, number of nonzero weight is 735232, zero is 313344
# layer: 297, number of nonzero weight is 1654272, zero is 705024
# layer: 300, number of nonzero weight is 954481, zero is 94095
# layer: 303, number of nonzero weight is 735232, zero is 313344
# layer: 306, number of nonzero weight is 1652895, zero is 706401
# layer: 309, number of nonzero weight is 954634, zero is 93942
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309]
# [0, 3, 6, 9, 15, 18, 21, 24, 27, 30, 33, 36, 39, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 294, 297, 300, 303, 306, 309]
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# mask Ready
# mask Done
# layer: 0, number of nonzero weight is 6615, zero is 2793
# layer: 3, number of nonzero weight is 2880, zero is 1216
# layer: 6, number of nonzero weight is 25749, zero is 11115
# layer: 9, number of nonzero weight is 11375, zero is 5009
# layer: 12, number of nonzero weight is 16384, zero is 0
# layer: 15, number of nonzero weight is 11520, zero is 4864
# layer: 18, number of nonzero weight is 25920, zero is 10944
# layer: 21, number of nonzero weight is 11003, zero is 5381
# layer: 24, number of nonzero weight is 11520, zero is 4864
# layer: 27, number of nonzero weight is 25407, zero is 11457
# layer: 30, number of nonzero weight is 11070, zero is 5314
# layer: 33, number of nonzero weight is 23040, zero is 9728
# layer: 36, number of nonzero weight is 97353, zero is 50103
# layer: 39, number of nonzero weight is 45597, zero is 19939
# layer: 42, number of nonzero weight is 131072, zero is 0
# layer: 45, number of nonzero weight is 45616, zero is 19920
# layer: 48, number of nonzero weight is 103437, zero is 44019
# layer: 51, number of nonzero weight is 44020, zero is 21516
# layer: 54, number of nonzero weight is 45884, zero is 19652
# layer: 57, number of nonzero weight is 100890, zero is 46566
# layer: 60, number of nonzero weight is 45155, zero is 20381
# layer: 63, number of nonzero weight is 46016, zero is 19520
# layer: 66, number of nonzero weight is 102375, zero is 45081
# layer: 69, number of nonzero weight is 45292, zero is 20244
# layer: 72, number of nonzero weight is 92160, zero is 38912
# layer: 75, number of nonzero weight is 403398, zero is 186426
# layer: 78, number of nonzero weight is 183493, zero is 78651
# layer: 81, number of nonzero weight is 524288, zero is 0
# layer: 84, number of nonzero weight is 183702, zero is 78442
# layer: 87, number of nonzero weight is 414153, zero is 175671
# layer: 90, number of nonzero weight is 177164, zero is 84980
# layer: 93, number of nonzero weight is 183382, zero is 78762
# layer: 96, number of nonzero weight is 414243, zero is 175581
# layer: 99, number of nonzero weight is 178368, zero is 83776
# layer: 102, number of nonzero weight is 183983, zero is 78161
# layer: 105, number of nonzero weight is 414720, zero is 175104
# layer: 108, number of nonzero weight is 174457, zero is 87687
# layer: 111, number of nonzero weight is 184071, zero is 78073
# layer: 114, number of nonzero weight is 414126, zero is 175698
# layer: 117, number of nonzero weight is 176268, zero is 85876
# layer: 120, number of nonzero weight is 184296, zero is 77848
# layer: 123, number of nonzero weight is 414720, zero is 175104
# layer: 126, number of nonzero weight is 175804, zero is 86340
# layer: 129, number of nonzero weight is 184295, zero is 77849
# layer: 132, number of nonzero weight is 414720, zero is 175104
# layer: 135, number of nonzero weight is 178840, zero is 83304
# layer: 138, number of nonzero weight is 184292, zero is 77852
# layer: 141, number of nonzero weight is 414720, zero is 175104
# layer: 144, number of nonzero weight is 180892, zero is 81252
# layer: 147, number of nonzero weight is 184299, zero is 77845
# layer: 150, number of nonzero weight is 414720, zero is 175104
# layer: 153, number of nonzero weight is 180816, zero is 81328
# layer: 156, number of nonzero weight is 184173, zero is 77971
# layer: 159, number of nonzero weight is 414720, zero is 175104
# layer: 162, number of nonzero weight is 182564, zero is 79580
# layer: 165, number of nonzero weight is 184314, zero is 77830
# layer: 168, number of nonzero weight is 414720, zero is 175104
# layer: 171, number of nonzero weight is 182412, zero is 79732
# layer: 174, number of nonzero weight is 184312, zero is 77832
# layer: 177, number of nonzero weight is 411390, zero is 178434
# layer: 180, number of nonzero weight is 181891, zero is 80253
# layer: 183, number of nonzero weight is 184315, zero is 77829
# layer: 186, number of nonzero weight is 413442, zero is 176382
# layer: 189, number of nonzero weight is 183326, zero is 78818
# layer: 192, number of nonzero weight is 184320, zero is 77824
# layer: 195, number of nonzero weight is 414054, zero is 175770
# layer: 198, number of nonzero weight is 183181, zero is 78963
# layer: 201, number of nonzero weight is 184320, zero is 77824
# layer: 204, number of nonzero weight is 414720, zero is 175104
# layer: 207, number of nonzero weight is 182944, zero is 79200
# layer: 210, number of nonzero weight is 184320, zero is 77824
# layer: 213, number of nonzero weight is 414720, zero is 175104
# layer: 216, number of nonzero weight is 181652, zero is 80492
# layer: 219, number of nonzero weight is 184320, zero is 77824
# layer: 222, number of nonzero weight is 414072, zero is 175752
# layer: 225, number of nonzero weight is 182200, zero is 79944
# layer: 228, number of nonzero weight is 184320, zero is 77824
# layer: 231, number of nonzero weight is 414720, zero is 175104
# layer: 234, number of nonzero weight is 181120, zero is 81024
# layer: 237, number of nonzero weight is 184320, zero is 77824
# layer: 240, number of nonzero weight is 414054, zero is 175770
# layer: 243, number of nonzero weight is 182802, zero is 79342
# layer: 246, number of nonzero weight is 184320, zero is 77824
# layer: 249, number of nonzero weight is 414720, zero is 175104
# layer: 252, number of nonzero weight is 183248, zero is 78896
# layer: 255, number of nonzero weight is 184320, zero is 77824
# layer: 258, number of nonzero weight is 414720, zero is 175104
# layer: 261, number of nonzero weight is 183400, zero is 78744
# layer: 264, number of nonzero weight is 184320, zero is 77824
# layer: 267, number of nonzero weight is 414720, zero is 175104
# layer: 270, number of nonzero weight is 183552, zero is 78592
# layer: 273, number of nonzero weight is 184320, zero is 77824
# layer: 276, number of nonzero weight is 414720, zero is 175104
# layer: 279, number of nonzero weight is 183247, zero is 78897
# layer: 282, number of nonzero weight is 367616, zero is 156672
# layer: 285, number of nonzero weight is 1654272, zero is 705024
# layer: 288, number of nonzero weight is 734055, zero is 314521
# layer: 291, number of nonzero weight is 2097152, zero is 0
# layer: 294, number of nonzero weight is 735232, zero is 313344
# layer: 297, number of nonzero weight is 1654272, zero is 705024
# layer: 300, number of nonzero weight is 734055, zero is 314521
# layer: 303, number of nonzero weight is 735232, zero is 313344
# layer: 306, number of nonzero weight is 1652895, zero is 706401
# layer: 309, number of nonzero weight is 734208, zero is 314368
# Test: [0/63]	Time 14.119 (14.119)	Loss 0.7357 (0.7357)	Prec@1 80.500 (80.500)	Prec@5 94.625 (94.625)
#  * Prec@1 63.278 Prec@5 85.754 Error@1 36.722
#
#
# >>>>> Accuracy_pruned:  63.278

# %%
# !nvidia-smi
# Out:
# Wed Oct  7 17:33:11 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.126.02   Driver Version: 418.126.02   CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:06:00.0 Off |                    0 |
# | N/A   36C    P0    58W / 300W |  21124MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM2...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   34C    P0    40W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla V100-SXM2...  On   | 00000000:0A:00.0 Off |                    0 |
# | N/A   34C    P0    42W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla V100-SXM2...  On   | 00000000:0B:00.0 Off |                    0 |
# | N/A   31C    P0    40W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   4  Tesla V100-SXM2...  On   | 00000000:85:00.0 Off |                    0 |
# | N/A   32C    P0    41W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   5  Tesla V100-SXM2...  On   | 00000000:86:00.0 Off |                    0 |
# | N/A   34C    P0    40W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   6  Tesla V100-SXM2...  On   | 00000000:89:00.0 Off |                    0 |
# | N/A   35C    P0    41W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   7  Tesla V100-SXM2...  On   | 00000000:8A:00.0 Off |                    0 |
# | N/A   33C    P0    42W / 300W |     11MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0     79464      C   /home/hongky/.conda/envs/mdc/bin/python    21111MiB |
# +-----------------------------------------------------------------------------+
